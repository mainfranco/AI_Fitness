# %%
from class_user_1 import User
import pickle
import sqlite3

# %%
mark = User('Mark', '001')

# %%
whitney = User('Whitney', '002')

# %%
whitney.dump_data()
# Out:
# Enter the table name you want to dump data into or 'exit' to quit: tokens_codes_log
# Columns in 'tokens_codes_log': id, user_id, last_date, fitbit_request_token, fitbit_access_token, fitbit_refresh_token, fitbit_user_id
# Enter value for last_date: 2024-03-01
# Enter value for fitbit_request_token: 1c2a840078753f8aeb1999d039a46a61da3092bd
# Enter value for fitbit_access_token: eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyM1JRWkMiLCJzdWIiOiI5TEo0TDIiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyYWN0IHJyZXMgcm94eSByd2VpIHJociBydGVtIHJzbGUiLCJleHAiOjE3MDkwNzY2OTMsImlhdCI6MTcwOTA0Nzg5M30.uaTwlMlyjKzrxpwWuo01sTuQPh6UhzmYY3HJ8jv5mkM
# Enter value for fitbit_refresh_token: ea9e873bf33586bebad667e120f93de0e32e596b05803754f36d99ae8da71b86
# An error occurred: 4 values for 6 columns

# %%
whitney.fitbit_request_token = "1c2a840078753f8aeb1999d039a46a61da3092bd"
whitney.fitbit_code_verifier = "-68xcle3eGoLW7KOZa_HGEHYfThDIayUP0T4WOEx0zp5GbnuVbGFKwuPCNvC6PT8kKrYiSsh07aUDYDiAlj9uQ"
whitney.fitbit_code_challenge = "ri85sDyAriV7wpL_CE3iZw4qgohwhG8zVtzcMynXA1s"
whitney.access_token_fitbit = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyM1JRWkMiLCJzdWIiOiI5TEo0TDIiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyYWN0IHJyZXMgcm94eSByd2VpIHJociBydGVtIHJzbGUiLCJleHAiOjE3MDkwNzY2OTMsImlhdCI6MTcwOTA0Nzg5M30.uaTwlMlyjKzrxpwWuo01sTuQPh6UhzmYY3HJ8jv5mkM"
whitney.refresh_token_fitbit = "ea9e873bf33586bebad667e120f93de0e32e596b05803754f36d99ae8da71b86"
whitney.user_id_fitbit = "9LJ4L2"
whitney.save_to_db()

# %%
query = input('Search Food: ')

mark.log_food_entry(query)
# Out:
# Search Food: french fries
# option: 1
# Champagne French Bakery Café French Fries
# tag id: c6405291212dc9382cdba8f8
# serving unit: serving
# serving quantity: 1
# calories per serving: 210
# -----------------------
# -----------------------
# option: 2
# Kroger Potatoes, French Fried, French Fries
# tag id: 51c35af697c3e69de4b00145
# serving unit: fries
# serving quantity: 17
# calories per serving: 100
# -----------------------
# -----------------------
# option: 3
# Shawarma Press French Fries, Portion for Shawarma Fries
# tag id: bd9d28140a9dd7b4b52c689e
# serving unit: Serving
# serving quantity: 1
# calories per serving: 370
# -----------------------
# -----------------------
# option: 4
# Ore-Ida French Fried Potatoes, Golden Fries
# tag id: 51c35f2f97c3e69de4b01b7a
# serving unit: pieces
# serving quantity: 14
# calories per serving: 90
# -----------------------
# -----------------------
# option: 5
# Blimpie French Fries, Large
# tag id: 15219037492146e1d5868d33
# ...

# %%
whitney.log_food_entry('eggs')
# Out:
# option: 1
# Easy Eggs Peeled Hard Cooked Eggs
# tag id: 620fa60b8de7ac000b446993
# serving unit: eggs
# serving quantity: 2
# calories per serving: 120
# -----------------------
# -----------------------
# option: 2
# Great Value Grade A Large White Eggs
# tag id: 57aa9fb2532c65b37873d05d
# serving unit: egg
# serving quantity: 1
# calories per serving: 70
# -----------------------
# -----------------------
# option: 3
# Friendly's Hash & Eggs, Egg Choice Scrambled Eggs (Eggs Only)
# tag id: d3ea72741e84bcd08a6a9a12
# serving unit: Serving
# serving quantity: 1
# calories per serving: 160
# -----------------------
# -----------------------
# option: 4
# Vital Farms Eggs, Alfresco
# tag id: 54ebd3a34627235720be1f08
# serving unit: egg
# serving quantity: 1
# calories per serving: 70
# -----------------------
# -----------------------
# option: 5
# Hilton Garden Inn Scrambled Eggs, Pasteurized Shell Eggs (2 Eggs)
# tag id: c64025112bf2a570e4410c63
# serving unit: Eggs
# ...

# %%
mark.pull_data()
# Out:
# Enter 'l' to show all tables, a table name to query it, or 'e' to quit: l
# Tables in the database:
# food_log
# sqlite_sequence
# exercises
# tokens_codes_log
# users
# exercise_sets
# Enter 'l' to show all tables, a table name to query it, or 'e' to quit: food_log
# (1, '001', 'Applesauce, Apple', 50, 0, 13, 0, 0, 0, 80, 11, '2024-03-01 17:36:14.888000', 'https://assets.syndigo.com/5388fa45-ab38-425f-a1c4-4efb68c17185')
# (2, '001', 'Potatoes, French Fried, French Fries', 176.47, 1.76, 30, 6.18, 0, 617.65, 458.82, 0.88, '2024-03-01 17:45:23.796201', 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png')
# (3, '001', 'Pre-Sliced Apples', 30, 0, 8, 0, 0, 0, 0, 6, '2024-03-01 17:45:33.746457', 'https://nutritionix-api.s3.amazonaws.com/550b404df42a6ae174f70aa3.jpeg')
# (4, '002', 'Hash & Eggs, Egg Choice Scrambled Eggs (Eggs Only)', 480, 42, 12, 30, 1320, 510, 0, 9, '2024-03-01 17:46:27.112931', 'https://d2eawub7utcl6.cloudfront.net/images/nix-apple-grey.png')
# ...

# %%
mark.log_exercise('bench press')
# Out:
# [1] Dumbbell Bench Press
# [2] Close-grip bench press
# [3] Incline dumbbell bench press
# [4] Barbell Bench Press - Medium Grip
# [5] Decline barbell bench press
# [6] Wide-grip bench press
# [7] Wide-Grip Decline Barbell Bench Press
# [8] Reverse-grip incline dumbbell bench press
# [9] Barbell Incline Bench Press Medium-Grip
# [10] Close-grip EZ-bar bench press
# choose exercise: 7
# Wide-Grip Decline Barbell Bench Press
# Weight for the set (lbs): 100
# Reps: 6
# Add another set? (y/n): n
# Exercise logged successfully.

# %%
mark.pull_data()
# Out:
# Enter 'list' to show all tables, a table name to query it, or 'exit' to quit: list
# Tables in the database:
# food_log_001
# sqlite_sequence
# workout_log_001
# tokens_codes_log_001
# users
# exercises_001
# exercise_sets_001
# food_log
# exercises
# tokens_codes_log
# exercise_sets
# Enter 'list' to show all tables, a table name to query it, or 'exit' to quit: exercise_sets
# (1, 1, 100, 15, '001')
# (2, 1, 100, 12, '001')

# %%
mark.pull_data()
# Out:
# (1, 1, 50, 4)
# (2, 2, 205, 8)
# (3, 2, 205, 6)
# (4, 2, 10, 6)
# (5, 3, 100, 5)
# (6, 3, 12, 12)

# %%
mark.pull_data('tokens_codes_log_002')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 mark.pull_data('tokens_codes_log_002')
#
# File ~\OneDrive\Desktop\Data Science Projects\Fitness Data Project\User_Class\class_user_1.py:820, in User.pull_data(self, table)
#     817 cursor = conn.cursor()
#     819 # Query the database for all entries in food_logs
# --> 820 cursor.execute(f'SELECT * FROM {table}')
#     822 # Fetch all rows from the query
#     823 rows = cursor.fetchall()
#
# OperationalError: no such table: tokens_codes_log_002

# %%
mark.get_request_token_fitbit()
# Out:
# Visit this URL in your web browser to authorize: https://www.fitbit.com/oauth2/authorize?client_id=23RQZC&response_type=code&scope=heartrate+sleep+weight+respiratory_rate+activity+oxygen_saturation+temperature&redirect_uri=https%3A%2F%2Flocalhost%3A3000%2Fcallback&code_challenge=OhpCMcUWeJfsMZnRMLQiADIKJJ1nnS3TfmEV30_mbZw&code_challenge_method=S256
# Paste Request Token: 96ea799512736c1e2bb8ef4fb19338349dbd174c
# code_verifier, code_challenge and request token saved succesfully

# %%
mark.access_refresh_tokens_fitbit()
# Out:
# Succesfull

# %%
mark.pull_data()
# Out:
# Enter 'l' to show all tables, a table name to query it, or 'e' to quit: l
# Tables in the database:
# food_log
# sqlite_sequence
# exercises
# tokens_codes_log
# users
# exercise_sets
# Enter 'l' to show all tables, a table name to query it, or 'e' to quit: tokens_codes_log
# (1, '001', '2024-03-01 17:52:46.359384', '96ea799512736c1e2bb8ef4fb19338349dbd174c', 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyM1JRWkMiLCJzdWIiOiJCWUI3U0siLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyYWN0IHJyZXMgcm94eSByd2VpIHJociBydGVtIHJzbGUiLCJleHAiOjE3MDkzNjU5NjYsImlhdCI6MTcwOTMzNzE2Nn0.ORqDU7aDGdWP7Ha5Z5vUqibHgE_tebf3EhAK50YtHyw', '846ef3abfdcba78bad203dbc5a9e353f2c0fb6e68d3e4103a772d9f0689ebc0d', 'BYB7SK')

# %%
mark.access_refresh_tokens_fitbit()
# Out:
# Need request token and or code verifier

# %%
mark.get_sleep_data('2024-02-10')
# Out:
# Good request
# {'pagination': {'afterDate': '2024-02-10',
#   'limit': 100,
#   'next': '',
#   'offset': 0,
#   'previous': '',
#   'sort': 'asc'},
#  'sleep': []}

# %%
whitney.pull_data('users')
# Out:
# ('00001', 'Mark', b'\x80\x04\x95S\x00\x00\x00\x00\x00\x00\x00\x8c\x08__main__\x94\x8c\x04User\x94\x93\x94)\x81\x94}\x94(\x8c\x04name\x94\x8c\x04Mark\x94\x8c\x02id\x94\x8c\x0500001\x94\x8c\x07db_path\x94\x8c\x0efitness_app.db\x94ub.')
# ('001', 'Mark', b'\x80\x04\x95U\x00\x00\x00\x00\x00\x00\x00\x8c\x0cclass_user_1\x94\x8c\x04User\x94\x93\x94)\x81\x94}\x94(\x8c\x04name\x94\x8c\x04Mark\x94\x8c\x02id\x94\x8c\x03001\x94\x8c\x07db_path\x94\x8c\x0efitness_app.db\x94ub.')
# ...

# %%
whitney.

# %%
mark.pull_data('users')
# Out:
# ('00001', 'Mark', b'\x80\x04\x95S\x00\x00\x00\x00\x00\x00\x00\x8c\x08__main__\x94\x8c\x04User\x94\x93\x94)\x81\x94}\x94(\x8c\x04name\x94\x8c\x04Mark\x94\x8c\x02id\x94\x8c\x0500001\x94\x8c\x07db_path\x94\x8c\x0efitness_app.db\x94ub.')
# ...
